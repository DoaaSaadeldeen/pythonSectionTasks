# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
# %matplotlib inline

# %%
G1=nx.Graph()#undirected
G1.add_node(5)
edges_to_add = [(1,2),(1,3),(1,4),(1,6),(2,3),(2,4),(3,6)]
G1.add_edges_from(edges_to_add)
nx.draw_networkx(G1,node_color="green")

# %%
def plot_degree_dist(G):
    degrees = G.degree()
    degrees = dict(degrees)
    values = sorted(set(degrees.values()))
    print(values)
    histo = [list(degrees.values()).count(x) for x in values]
    P_k = [x / G.order() for x in histo]
    print(len(P_k))
    
    plt.figure()
    plt.bar(values, P_k)
    plt.xlabel("k",fontsize=20)
    plt.ylabel("p(k)", fontsize=20)
    plt.title("Degree Distribution", fontsize=20)
    
    plt.show()
    plt.figure()
    plt.grid(False)
    plt.loglog(values, P_k, "bo")
    plt.xlabel("k", fontsize=20)
    plt.ylabel("log p(k)", fontsize=20)
    plt.title("log Degree Distribution")
    plt.show()
    plt.show()

# %%
plot_degree_dist(G1)
# Out:
# [0, 2, 3, 4]
# 4

# %%
Adj = nx.adjacency_matrix(G1).todense()

# %%
G2 = nx.DiGraph(directed=True)#directed
G2.add_node(5)
edges_to_add2 = [(1,2),(2,4),(4,1),(6,1),(6,3),(3,1),(3,2),(2,3)]
G2.add_edges_from(edges_to_add2)
#nx.draw_networkx(G2)

# %%
plot_degree_dist(G2)
# Out:
# [0, 2, 4]
# 3

# %%
Adj2 = nx.adjacency_matrix(G2).todense()
